# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('bike sharing by day.csv')

# %%
data.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
data.dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
data.drop(['casual','registered','instant'],axis=1,inplace=True)

# %%
data.describe()
# Out:
#            season          yr        mnth     holiday     weekday  workingday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     2.496580    0.500684    6.519836    0.028728    2.997264    0.683995
# std      1.110807    0.500342    3.451913    0.167155    2.004787    0.465233
# min      1.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 25%      2.000000    0.000000    4.000000    0.000000    1.000000    0.000000
# 50%      3.000000    1.000000    7.000000    0.000000    3.000000    1.000000
# 75%      3.000000    1.000000   10.000000    0.000000    5.000000    1.000000
# max      4.000000    1.000000   12.000000    1.000000    6.000000    1.000000
#
#        weathersit        temp       atemp         hum   windspeed          cnt
# count  731.000000  731.000000  731.000000  731.000000  731.000000   731.000000
# mean     1.395349    0.495385    0.474354    0.627894    0.190486  4504.348837
# ...

# %% [markdown]
# # Uni Varient Analysis

# %% [markdown]
# # Categorical Variables

# %% [markdown]
# # data['cnt']

# %%
sns.boxplot(data['cnt'])

# %%
sns.distplot(data['cnt'])

# %% [markdown]
# From the above boxplot and distutibution plot we can state that:
#     1)There are no outlayers in data['cnt'].
#     2)The disturibution is normal because the spread between Q1-Q2,Q2-Q3 looks similar.

# %% [markdown]
# # data['season']#

# %%
data['season'].value_counts().plot.bar()

# %%
data['season'].value_counts().plot.pie()

# %% [markdown]
# From the above two graphs we can interpret that the seasons are equal in proportions throughout the data

# %% [markdown]
# # data['year']

# %%
data['yr'].value_counts().plot.bar()

# %%
data['yr'].value_counts().plot.pie()

# %% [markdown]
# # data['month']

# %%
data['mnth'].value_counts().plot.bar()

# %% [markdown]
# # data['Holiday']

# %%
data['holiday'].value_counts().plot.bar()

# %%
sns.countplot(data['holiday'])

# %% [markdown]
# we can say that bikes are taken significantly more on working days than holidays

# %% [markdown]
# # data['weekday']

# %%
sns.countplot(data['weekday'])

# %% [markdown]
#  There is no significant different between weekdays

# %% [markdown]
# # data['workingday']

# %%
data['workingday'].value_counts().plot.bar()

# %% [markdown]
# On holidays the bikes taken are more comparied to working days

# %% [markdown]
# # data['weathersit']

# %%
sns.countplot(data['weathersit'])

# %% [markdown]
# 1: Clear, Few clouds, Partly cloudy, Partly cloudy
# 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
# 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
# 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
# bikes taken during 1>2>>3 but during 4 no bikes had been rented

# %%
data.head(1)
# Out:
#        dteday  season  yr  mnth  holiday  weekday  workingday  weathersit  \
# 0  2011-01-01       1   0     1        0        6           0           2
#
#        temp     atemp       hum  windspeed  cnt
# 0  0.344167  0.363625  0.805833   0.160446  985

# %% [markdown]
# # Continuous variables

# %% [markdown]
# # data['temp']

# %%
sns.distplot(data['temp'])

# %%
sns.boxplot(data['temp'])

# %% [markdown]
# # data['atemp']

# %%
sns.distplot(data['atemp'])

# %%
sns.boxplot(data['temp'])

# %% [markdown]
# # data['humidity']

# %%
sns.distplot(data['hum'])

# %%
sns.boxplot(data['hum'])

# %% [markdown]
# # data['windspeed']

# %%
sns.distplot(data['windspeed'])

# %%
sns.boxplot(data['windspeed'])

# %% [markdown]
# # Bi-Varient Analysis

# %% [markdown]
# # categorical vs continous

# %% [markdown]
# # data['cnt'] vs data['season']

# %%
sns.barplot(data['season'],data['cnt'],estimator=np.mean)

# %%
sns.boxplot(data['season'],data['cnt'])

# %% [markdown]
# # data['yr'] vs data['cnt']

# %%
sns.barplot(data['yr'],data['cnt'])

# %%
sns.boxplot(data['yr'],data['cnt'])

# %% [markdown]
# # data['mnth'] vs data['cnt']

# %%
data['cnt'].groupby(data['mnth']).agg('mean').plot.bar()

# %%
sns.boxplot(data['mnth'],data['cnt'])

# %% [markdown]
# # data['holiday'] vs data['cnt']

# %%
data['cnt'].groupby(data['holiday']).agg('mean').plot.bar()

# %%
sns.boxplot(data['holiday'],data['cnt'])

# %% [markdown]
# # data['weekday'] vs data['cnt']

# %%
sns.barplot(data['weekday'],data['cnt'])

# %%
sns.boxplot(data['weekday'],data['cnt'])

# %% [markdown]
# # data['weathersit'] vs data['cnt']

# %%
sns.barplot(data['weathersit'],data['cnt'])

# %%
sns.boxplot(data['weathersit'],data['cnt'])

# %% [markdown]
# # *continous vs continous*

# %%
data.head()
# Out:
#        dteday  season  yr  mnth  holiday  weekday  workingday  weathersit  \
# 0  2011-01-01       1   0     1        0        6           0           2
# 1  2011-01-02       1   0     1        0        0           0           2
# 2  2011-01-03       1   0     1        0        1           1           1
# 3  2011-01-04       1   0     1        0        2           1           1
# 4  2011-01-05       1   0     1        0        3           1           1
#
#        temp     atemp       hum  windspeed   cnt
# 0  0.344167  0.363625  0.805833   0.160446   985
# 1  0.363478  0.353739  0.696087   0.248539   801
# 2  0.196364  0.189405  0.437273   0.248309  1349
# 3  0.200000  0.212122  0.590435   0.160296  1562
# 4  0.226957  0.229270  0.436957   0.186900  1600

# %% [markdown]
# # data['temp'] vs data['cnt']

# %%
sns.scatterplot(data['temp'],data['cnt'])

# %%
sns.jointplot(data['temp'],data['cnt'],kind='kde')

# %% [markdown]
# # data['hum'] vs data['cnt']

# %%
sns.scatterplot(data['hum'],data['cnt'])

# %%
sns.jointplot(data['hum'],data['cnt'],kind='kde')

# %% [markdown]
# # data['windspeed'] vs data['cnt']

# %%
sns.scatterplot(data['windspeed'],data['cnt'])

# %%
sns.jointplot(data['windspeed'],data['cnt'],kind='kde')

# %% [markdown]
# # pairplot()

# %%
sns.pairplot(data)

# %% [markdown]
# # Heatmap

# %%
plt.figure(figsize=(8,8))
sns.heatmap(data.corr(),annot=True)

# %% [markdown]
# # Statistical Analysis

# %% [markdown]
# # data['yr'] vs data['cnt']

# %%
from scipy.stats import ttest_ind

# %%
t_statistic,p_value=ttest_ind(data[data['yr']==1]['cnt'],data[data['yr']==0]['cnt'])
print(t_statistic,p_value)
# Out:
# 18.57123004907546 2.4835399044508365e-63

# %% [markdown]
# # data['holiday'] vs data['cnt']

# %%
t_statistic,p_value=ttest_ind(data[data['holiday']==1]['cnt'],data[data['holiday']==0]['cnt'])
print(t_statistic,p_value)
# Out:
# -1.8497137724448645 0.06475935792611008

# %% [markdown]
# # data['workingday'] vs data['cnt']

# %%
t_statistic,p_value=ttest_ind(data[data['workingday']==1]['cnt'],data[data['workingday']==0]['cnt'])
print(t_statistic,p_value)
# Out:
# 1.6543102137118633 0.09849496160024915

# %% [markdown]
# # data['mnth'] vs data['cnt']

# %%
import statsmodels.api         as     sm
from   statsmodels.formula.api import ols
 
mod = ols('mnth ~ cnt', data = data).fit()
aov_table = sm.stats.anova_lm(mod, typ=2)
print(aov_table)
# Out:
#                sum_sq     df          F        PR(>F)
# cnt        681.847966    1.0  62.004625  1.243112e-14
# Residual  8016.614415  729.0        NaN           NaN

# %% [markdown]
# # data['weekday'] vs data['cnt']

# %%
import statsmodels.api         as     sm
from   statsmodels.formula.api import ols
 
mod = ols('weekday ~ cnt', data = data).fit()
aov_table = sm.stats.anova_lm(mod, typ=2)
print(aov_table)
# Out:
#                sum_sq     df         F    PR(>F)
# cnt         13.345608    1.0  3.331091  0.068391
# Residual  2920.648920  729.0       NaN       NaN

# %% [markdown]
# # data['weathersit'] vs data['cnt']

# %%
import statsmodels.api         as     sm
from   statsmodels.formula.api import ols
 
mod = ols('weathersit ~ cnt', data = data).fit()
aov_table = sm.stats.anova_lm(mod, typ=2)
print(aov_table)
# Out:
#               sum_sq     df          F        PR(>F)
# cnt        19.169192    1.0  70.729298  2.150976e-16
# Residual  197.574995  729.0        NaN           NaN

# %% [markdown]
# # data['temp']/data['humidity']/data['windspeed'] vs data['cnt']

# %%
data_c=data[['temp','hum','windspeed','cnt']]

# %%
sns.heatmap(data_c.corr(),annot=True)

# %%
data_c.corr()
# Out:
#                temp       hum  windspeed       cnt
# temp       1.000000  0.126963  -0.157944  0.627494
# hum        0.126963  1.000000  -0.248489 -0.100659
# windspeed -0.157944 -0.248489   1.000000 -0.234545
# cnt        0.627494 -0.100659  -0.234545  1.000000

# %% [markdown]
# # OLS Method:

# %%
import statsmodels.api as sm

# %%
X=data.drop('cnt',axis=1)
y=data['cnt']

# %%
from statsmodels.tools import add_constant as add_constant

# %%
X_constant=add_constant(X)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2495: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
X_constant
# Out:
#      const      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0      1.0  2011-01-01       1   0     1        0        6           0
# 1      1.0  2011-01-02       1   0     1        0        0           0
# 2      1.0  2011-01-03       1   0     1        0        1           1
# 3      1.0  2011-01-04       1   0     1        0        2           1
# 4      1.0  2011-01-05       1   0     1        0        3           1
# ..     ...         ...     ...  ..   ...      ...      ...         ...
# 726    1.0  2012-12-27       1   1    12        0        4           1
# 727    1.0  2012-12-28       1   1    12        0        5           1
# 728    1.0  2012-12-29       1   1    12        0        6           0
# 729    1.0  2012-12-30       1   1    12        0        0           0
# 730    1.0  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed
# 0             2  0.344167  0.363625  0.805833   0.160446
# ...

# %%
result=sm.OLS(y,X_constant).fit()
result=ols_model.fit()
print(result.summary())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-6de5b5c9f3e9> in <module>
# ----> 1 result=sm.OLS(y,X_constant).fit()
#       2 #result=ols_model.fit()
#       3 print(result.summary())
#
# ~\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     836                  **kwargs):
#     837         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 838                                   hasconst=hasconst, **kwargs)
#     839         if "weights" in self._init_keys:
#     840             self._init_keys.remove("weights")
#
# ~\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     682             weights = weights.squeeze()
# ...

# %% [markdown]
# # Linear Regression Statistics

# %%
import statsmodels.api as sm

# %%
X=data.drop('cnt',axis=1)
y=data['cnt']

# %%
X.drop('workingday',axis=1,inplace=True)

# %%
from statsmodels.tools import add_constant as add_constant

# %%
X_constant=add_constant(X)

# %%
 from  statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns
vif

# %%
X.corr()

# %% [markdown]
# # polynomial regression

# %%
y=data['cnt']
X=data.drop('cnt',axis=1)

# %%
from sklearn.preprocessing import PolynomialFeatures
pf=PolynomialFeatures()
x=pf.fit_transform(X)

# %%
feature_names = pf.get_feature_names(X.columns)
x = pd.DataFrame(x, columns = feature_names)

# %%
cols = list(x.columns)
pmax = 1
while (len(cols)>0):
    p= []
    X_1 = x[cols]
    X_1 = sm.add_constant(X_1)
    model = sm.OLS(y,X_1).fit()
    p = pd.Series(model.pvalues,index = cols)      
    pmax = max(p)
    feature_with_p_max = p.idxmax()
    if(pmax>0.05):
        cols.remove(feature_with_p_max)
    else:
        break
selected_features_BE = cols
print(selected_features_BE)

# %%
X_F=x[selected_features_BE]

# %%
y=data['cnt']

# %% [markdown]
# # Linear Regression model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
data=pd.read_csv('bike sharing by day.csv')

# %%
data.head(3)

# %%
data.drop(['casual','registered','instant','dteday','atemp','workingday'],axis=1,inplace=True)

# %%
data.head(1)

# %%
data['yr'].replace({0:2011,1:2012},inplace=True)

# %%
data=pd.get_dummies(data=data,columns=['season','yr','mnth','holiday','weekday','weathersit'],drop_first=True)

# %%
data.head(1)

# %%
X=data.drop('cnt',axis=1)
y=data['cnt']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=40)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape

# %%
lr.fit(X_train,y_train)

# %%
from sklearn.metrics import r2_score

# %%
y_train_pred=lr.predict(X_train)

# %%
print(r2_score(y_train,y_train_pred))

# %%
y_test_pred=lr.predict(X_test)

# %%
print(r2_score(y_test,y_test_pred))

# %%
coef=pd.DataFrame(list(zip(X.columns,lr.coef_)))
coef.columns=['cols','coefs']

# %%
print(coef)

# %% [markdown]
# # Cross Validation Technique

# %%
import sklearn.model_selection as model_selection
from sklearn.model_selection import KFold, cross_val_score

# %%
kfold = model_selection.KFold(shuffle = True,n_splits= 15,random_state=0)
cv_results = model_selection.cross_val_score(lr,X,y,cv = kfold)

# %%
print(cv_results)

# %%
plt.plot(cv_results)
plt.show()

# %%
print(np.mean(cv_results))

# %%
print(np.var(cv_results,ddof=1))

# %% [markdown]
# # Feature Selection using RFE

# %%
from sklearn.feature_selection import RFE
model=LinearRegression()
rfe=RFE(model,10)

X_rfe=rfe.fit_transform(X_train,y_train)
model.fit(X_rfe,y_train)

print(rfe.support_)
print(rfe.ranking_)
X_r=pd.DataFrame(list(zip(X_train.columns,rfe.support_,rfe.ranking_)))
X_r.columns=['col_name','support','ranking']
print(X_r)

# %%
col=X_r[X_r['ranking']==1]['col_name']

# %%
no_of_cols=len(X_train.columns)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=45)

# %%
score_list=[]
for n in range(no_of_cols):
    model=LinearRegression()
    rfe=RFE(model,n+1)
    X_train_rfe=rfe.fit_transform(X_train,y_train)
    model.fit(X_train_rfe,y_train)
    
    X_test_rfe=rfe.transform(X_test)
    score=model.score(X_test_rfe,y_test)
    
    score_list.append(score)

# %%
plt.plot(score_list)
plt.show()

# %%
sel_col=list(col)
sel_col

# %%
X=data[sel_col]

# %%
y=data['cnt']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=52)

# %%
lr.fit(X_train,y_train)

# %%
y_train_pred=lr.predict(X_train)

# %%
r2_score(y_train_pred,y_train)

# %%
y_test_pred=lr.predict(X_test)

# %%
r2_score(y_test_pred,y_test)

# %% [markdown]
# # CrossValidation

# %%
kfold = model_selection.KFold(shuffle = True,n_splits= 15,random_state=0)
cv_results = model_selection.cross_val_score(lr,X,y,cv = kfold)

# %%
print(cv_results)

# %%
print(cv_results.mean())

# %% [markdown]
# # Regularization

# %%
from sklearn.linear_model import Lasso,LassoCV,Ridge,RidgeCV,ElasticNet

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
data=pd.read_csv('bike sharing by day.csv')

# %%
data.drop(['casual','registered','instant','dteday','atemp','workingday'],axis=1,inplace=True)

# %%
data['yr'].replace({0:2011,1:2012},inplace=True)

data=pd.get_dummies(data=data,columns=['season','yr','mnth','holiday','weekday','weathersit'],drop_first=True)

# %%
X=data.drop('cnt',axis=1)
y=data['cnt']

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures()
Xp=poly.fit_transform(X)

# %%
Xp=pd.DataFrame(Xp,columns=poly.get_feature_names(X.columns))

# %%
Xp.shape

# %%
no_of_cols=len(X_train.columns)
X_train,X_test,y_train,y_test=train_test_split(Xp,y,test_size=0.30,random_state=45)

# %%
score_list=[]
for n in range(100):
    model=LinearRegression()
    rfe=RFE(model,n+1)
    X_train_rfe=rfe.fit_transform(X_train,y_train)
    model.fit(X_train_rfe,y_train)
    
    score=model.score(X_train_rfe,y_train)
    score_list.append(score)

# %%
plt.plot(score_list)
plt.show()

# %%
from sklearn.feature_selection import RFE
model=LinearRegression()
rfe=RFE(model,50)

X_rfe=rfe.fit_transform(X_train,y_train)
model.fit(X_rfe,y_train)

print(rfe.support_)
print(rfe.ranking_)
X_r=pd.DataFrame(list(zip(X_train.columns,rfe.support_,rfe.ranking_)))
X_r.columns=['col_name','support','ranking']
print(X_r)

# %%
col=X_r[X_r['ranking']==1]['col_name']

# %%
sel_col=list(col)
sel_col

# %%
X=Xp[sel_col]
y=data['cnt']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=45,test_size=0.30)

# %%
lasso=Lasso(alpha=0.25,max_iter=50000)
lasso.fit(X_train,y_train)

# %%
C=pd.DataFrame(list(zip(X_train.columns,lasso.coef_)))

# %%
C.columns=['col','coef']

# %%
C

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
n_alphas=50
alphas=np.linspace(0.01,0.1)
lasso_cv=LassoCV(alphas=alphas,cv=3,random_state=42,max_iter=50000)
lasso_cv.fit(Xp,y)

# %%
lasso_cv.alpha_

# %%
lasso=Lasso(alpha=1,max_iter=50000)
lasso.fit(X_train,y_train)

# %%
y_train_pred=lasso.predict(X_train)
y_test_pred=lasso.predict(X_test)

print(r2_score(y_train_pred,y_train))
print(r2_score(y_test_pred,y_test))

# %% [markdown]
# # Ridge

# %%
ridge=Ridge(alpha=0.5)
ridge.fit(X_train,y_train)

pd.DataFrame(ridge.coef_, X_train.columns,columns=['coef'])

# %%
n_alphas=100
alphas=np.logspace(-2,0)
ridge_cv=RidgeCV(alphas=alphas,store_cv_values=True)
ridge_cv.fit(Xp,y)
ridge_cv.alpha_

# %%
ridge=Ridge(alpha=0.2682695795279725)

# %%
10**1.5

# %%
np.logspace(0,2,4)

# %%
np.linspace(0,2,4)

# %%
outliers = pd.DataFrame()
for col in num_cols:    
    q1 = beer[col].quantile(0.25)    # First Quartile
    q3 = beer[col].quantile(0.75)    # Third Quartile
    iqr = q3 - q1                            # Inter Quartile Range

    ll = q1 - 1.5*iqr                        # Lower Limit
    ul = q3 + 1.5*iqr                        # Upper Limit

    outliers = pd.concat([outliers, beer[(beer[col] < ll) | (beer[col] > ul)]]) # append outliers
    beer = beer[(beer[col] >= ll) & (beer[col] <= ul)]                          # filter outliers

# %%
sklearn.metrics.cohen_kappa_score(y1, y2, labels=None, weights=None, sample_weight=None) #kappa
